# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **FICHIER DATA STUDENTS**

# %%
data_students = pd.read_csv("BDD_initial/Students Social Media Addiction.csv", sep=",", index_col=0)
data_students.head()
# Out:
#             Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# Student_ID
# 1            19  Female  Undergraduate  Bangladesh                    5.2
# 2            22    Male       Graduate       India                    2.1
# 3            20  Female  Undergraduate         USA                    6.0
# 4            18    Male    High School          UK                    3.0
# 5            21    Male       Graduate      Canada                    4.5
#
#            Most_Used_Platform Affects_Academic_Performance  \
# Student_ID
# 1                   Instagram                          Yes
# 2                     Twitter                           No
# 3                      TikTok                          Yes
# 4                     YouTube                           No
# 5                    Facebook                          Yes
#
#             Sleep_Hours_Per_Night  Mental_Health_Score Relationship_Status  \
# Student_ID
# 1                             6.5                    6     In Relationship
# 2                             7.5                    8              Single
# 3                             5.0                    5         Complicated
# 4                             7.0                    7              Single
# 5                             6.0                    6     In Relationship
#
#             Conflicts_Over_Social_Media  Addicted_Score
# Student_ID
# 1                                     3               8
# 2                                     0               3
# 3                                     4               9
# 4                                     1               4
# 5                                     2               7

# %%
sns.set_theme(style="whitegrid")
#param pour visualisations

# %% [markdown]
# **Distribution des heures d'utilisation quotidienne**
# Ce graphique montre combien d'heures par jour les étudiants utilisent les reseaux sociaux. Il permet de voir que la majorité des étudiants se situe entre les 4 et les 5 heures par jour.

# %%
data_students["Avg_Daily_Usage_Hours"].mean()
# Out:
# np.float64(4.918723404255319)

# %%
fig, ax = plt.subplots()
ax.hist(data_students["Avg_Daily_Usage_Hours"], bins=20, color="#4C72B0", edgecolor="white")
ax.set_title("Distribution des heures d'utilisation quotidienne")
ax.set_xlabel("Heures par jour")
ax.set_ylabel("Nombre d'étudiants")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Fréquence du score d'addiction (barre frequence)**
# Ici on vois répresente combiend d'etudiants ont chaque score de d'addiction (de 1 à 10).
# On remarque que 209 étudiants déclarent un score d'addiction de 7.

# %%
fig, ax = plt.subplots()
compte = data_students["Addicted_Score"].value_counts().sort_index()
ax.bar(compte.index, compte.values, color="orange", edgecolor="white")
ax.set_title("Fréquence du score d'addiction")
ax.set_xlabel("Score d'addiction (1–10)")
ax.set_ylabel("Nombre d'étudiants")
ax.set_xticks(compte.index)
plt.tight_layout()
plt.show()
compte.values.max()
# Out:
# np.int64(209)

# %% [markdown]
# **Score d'addiction par genre**
# Le graphique compare le niveau d'addiction entes les femmes et les hommes. La boîte réprente où se concentrent 50% des valeurs, et la ligne centrale est la mediane. On remarque que, dans ce jeux de données, les femmes déclarent un niveau d'addiction plus élévé que les hommes.

# %%
fig, ax = plt.subplots()
sns.boxplot(
    data=data_students,
    x="Gender",
    y="Addicted_Score",
    palette={"Female": "pink", "Male": "lightblue"},
    width=0.5,
    ax=ax,
)
ax.set_title("Score d'addiction selon le genre")
ax.set_xlabel("Genre")
ax.set_ylabel("Score d'addiction")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\leaca\AppData\Local\Temp\ipykernel_26168\3988987996.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %% [markdown]
# **Heures d'utilisation par niveau academique (violin plot)**
# Le violin plot montre comment varie l'utilisation quotidienne des réseaux sociaux selon le niveau d'études (Lycée, Licence ou Master).
# Ici on remarque que:
# - Les **lycéens** ont une utilisation très concétré autour de 5-6 heures par jours, avec peu de variation (forme du violon étroite)
# - Les **étudiants** en licence presenten une distribution plus large et plus variée. Les valeurs vont de 2h jusqu'à presque 9h par jour.
# - Les **étudiants** en master ont une utilisation conentée autour de 4.5h par jour, avec une utilisation un peu plus régulière et modérée.

# %%
ordre = ["High School", "Undergraduate", "Graduate"]
fig, ax = plt.subplots()
sns.violinplot(
    data=data_students,
    x="Academic_Level",
    y="Avg_Daily_Usage_Hours",
    order=ordre,
    palette="Set2",
    inner="quartile",
    ax=ax,
)
ax.set_title("Heures d'utilisation par niveau académique")
ax.set_xlabel("Niveau académique")
ax.set_ylabel("Heures par jour")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\leaca\AppData\Local\Temp\ipykernel_26168\2623365973.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(

# %% [markdown]
# **Santé mentale moyenne selon le score addiction**
# Ce graphique met en relation le score d'addiction et la santé mentale moyenne. La tendence est presque parfaitement linéaire: plus le score d'addicition est élevé, plus la santé mentale se dégrade.
# La descente est réguliere ce qui renforce l'idée d'une correlation négative forte entre les deux variables.
# Cependant on peut pas affimer avec certitude que c'est l'addiction qui cause les problèmes de santé mentale. On peut pas nécessairement parler de causalité.

# %%
moyennes = data_students.groupby("Addicted_Score")["Mental_Health_Score"].mean()

fig, ax = plt.subplots()
ax.errorbar(
    moyennes.index,
    moyennes.values,
    fmt="o-",
    color="red",
    capsize=5,
    linewidth=2,
    markersize=7,
)
ax.set_title("Santé mentale moyenne selon le score d'addiction")
ax.set_xlabel("Score d'addiction")
ax.set_ylabel("Santé mentale (moyenne)")
ax.set_xticks(moyennes.index)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Plateforme la plus utilisée**
# Le graphique montre quelles sont les plateformes les plus utilisées par les étudiants de l'échantillon

# %%
fig, ax = plt.subplots(figsize=(8, 6))
compte = data_students["Most_Used_Platform"].value_counts()
ax.barh(compte.index, compte.values,
        color=sns.color_palette("Set2", len(compte)))
ax.set_title("Plateforme la plus utilisée")
ax.set_xlabel("Nombre d'étudiants")
plt.tight_layout()
plt.show()

# %%
data_students2 = data_students.copy()

#variables à transformer de texte en nombre

categorical_cols = data_students2.select_dtypes(include='object').columns
print(f"Variables catégorielles à encoder : {list(categorical_cols)}")
# Out:
# Variables catégorielles à encoder : ['Gender', 'Academic_Level', 'Country', 'Most_Used_Platform', 'Affects_Academic_Performance', 'Relationship_Status']
# C:\Users\sidsm\AppData\Local\Temp\ipykernel_15804\3845327333.py:5: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = data_students2.select_dtypes(include='object').columns

# %%
from sklearn.preprocessing import LabelEncoder

label_encoders = {}
for col in categorical_cols:
    le = LabelEncoder()
    data_students2[col] = le.fit_transform(data_students2[col])
    label_encoders[col] = le
    print(f"  {col}: {dict(zip(le.classes_, le.transform(le.classes_)))}")

print("\nAperçu après encodage :")
data_students2.head()
# Out:
#   Gender: {'Female': np.int64(0), 'Male': np.int64(1)}
#   Academic_Level: {'Graduate': np.int64(0), 'High School': np.int64(1), 'Undergraduate': np.int64(2)}
#   Country: {'Afghanistan': np.int64(0), 'Albania': np.int64(1), 'Andorra': np.int64(2), 'Argentina': np.int64(3), 'Armenia': np.int64(4), 'Australia': np.int64(5), 'Austria': np.int64(6), 'Azerbaijan': np.int64(7), 'Bahamas': np.int64(8), 'Bahrain': np.int64(9), 'Bangladesh': np.int64(10), 'Belarus': np.int64(11), 'Belgium': np.int64(12), 'Bhutan': np.int64(13), 'Bolivia': np.int64(14), 'Bosnia': np.int64(15), 'Brazil': np.int64(16), 'Bulgaria': np.int64(17), 'Canada': np.int64(18), 'Chile': np.int64(19), 'China': np.int64(20), 'Colombia': np.int64(21), 'Costa Rica': np.int64(22), 'Croatia': np.int64(23), 'Cyprus': np.int64(24), 'Czech Republic': np.int64(25), 'Denmark': np.int64(26), 'Ecuador': np.int64(27), 'Egypt': np.int64(28), 'Estonia': np.int64(29), 'Finland': np.int64(30), 'France': np.int64(31), 'Georgia': np.int64(32), 'Germany': np.int64(33), 'Ghana': np.int64(34), 'Greece': np.int64(35), 'Hong Kong': np.int64(36), 'Hungary': np.int64(37), 'Iceland': np.int64(38), 'India': np.int64(39), 'Indonesia': np.int64(40), 'Iraq': np.int64(41), 'Ireland': np.int64(42), 'Israel': np.int64(43), 'Italy': np.int64(44), 'Jamaica': np.int64(45), 'Japan': np.int64(46), 'Jordan': np.int64(47), 'Kazakhstan': np.int64(48), 'Kenya': np.int64(49), 'Kosovo': np.int64(50), 'Kuwait': np.int64(51), 'Kyrgyzstan': np.int64(52), 'Latvia': np.int64(53), 'Lebanon': np.int64(54), 'Liechtenstein': np.int64(55), 'Lithuania': np.int64(56), 'Luxembourg': np.int64(57), 'Malaysia': np.int64(58), 'Maldives': np.int64(59), 'Malta': np.int64(60), 'Mexico': np.int64(61), 'Moldova': np.int64(62), 'Monaco': np.int64(63), 'Montenegro': np.int64(64), 'Morocco': np.int64(65), 'Nepal': np.int64(66), 'Netherlands': np.int64(67), 'New Zealand': np.int64(68), 'Nigeria': np.int64(69), 'North Macedonia': np.int64(70), 'Norway': np.int64(71), 'Oman': np.int64(72), 'Pakistan': np.int64(73), 'Panama': np.int64(74), 'Paraguay': np.int64(75), 'Peru': np.int64(76), 'Philippines': np.int64(77), 'Poland': np.int64(78), 'Portugal': np.int64(79), 'Qatar': np.int64(80), 'Romania': np.int64(81), 'Russia': np.int64(82), 'San Marino': np.int64(83), 'Serbia': np.int64(84), 'Singapore': np.int64(85), 'Slovakia': np.int64(86), 'Slovenia': np.int64(87), 'South Africa': np.int64(88), 'South Korea': np.int64(89), 'Spain': np.int64(90), 'Sri Lanka': np.int64(91), 'Sweden': np.int64(92), 'Switzerland': np.int64(93), 'Syria': np.int64(94), 'Taiwan': np.int64(95), 'Tajikistan': np.int64(96), 'Thailand': np.int64(97), 'Trinidad': np.int64(98), 'Turkey': np.int64(99), 'UAE': np.int64(100), 'UK': np.int64(101), 'USA': np.int64(102), 'Ukraine': np.int64(103), 'Uruguay': np.int64(104), 'Uzbekistan': np.int64(105), 'Vatican City': np.int64(106), 'Venezuela': np.int64(107), 'Vietnam': np.int64(108), 'Yemen': np.int64(109)}
#   Most_Used_Platform: {'Facebook': np.int64(0), 'Instagram': np.int64(1), 'KakaoTalk': np.int64(2), 'LINE': np.int64(3), 'LinkedIn': np.int64(4), 'Snapchat': np.int64(5), 'TikTok': np.int64(6), 'Twitter': np.int64(7), 'VKontakte': np.int64(8), 'WeChat': np.int64(9), 'WhatsApp': np.int64(10), 'YouTube': np.int64(11)}
#   Affects_Academic_Performance: {'No': np.int64(0), 'Yes': np.int64(1)}
#   Relationship_Status: {'Complicated': np.int64(0), 'In Relationship': np.int64(1), 'Single': np.int64(2)}
#
# Aperçu après encodage :
#             Age  Gender  Academic_Level  Country  Avg_Daily_Usage_Hours  \
# Student_ID
# 1            19       0               2       10                    5.2
# 2            22       1               0       39                    2.1
# 3            20       0               2      102                    6.0
# 4            18       1               1      101                    3.0
# 5            21       1               0       18                    4.5
#
#             Most_Used_Platform  Affects_Academic_Performance  \
# Student_ID
# 1                            1                             1
# 2                            7                             0
# 3                            6                             1
# 4                           11                             0
# 5                            0                             1
#
#             Sleep_Hours_Per_Night  Mental_Health_Score  Relationship_Status  \
# Student_ID
# 1                             6.5                    6                    1
# 2                             7.5                    8                    2
# 3                             5.0                    5                    0
# 4                             7.0                    7                    2
# 5                             6.0                    6                    1
#
#             Conflicts_Over_Social_Media  Addicted_Score
# Student_ID
# 1                                     3               8
# 2                                     0               3
# 3                                     4               9
# 4                                     1               4
# 5                                     2               7

# %%
sns.heatmap(data_students2.corr(), annot=False, cmap="coolwarm", linewidths=0.5)
# Out:
# <Axes: >
