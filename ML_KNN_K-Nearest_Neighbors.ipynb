# %% [markdown]
# KNN (K-Nearest Neigbors)

# %% [markdown]
# 1. Import des librairies

# %%
#%pip install scikit-learn
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# 2. Normalisation des données

# %%
scaler = StandardScaler()
X_train = ['Age', 'Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night','Mental_Health_Score', 'Conflicts_Over_Social_Media']
X_test = ['Gender_enc', 'Academic_Level_enc', 'Most_Used_Platform_enc', 'Affects_Academic_Performance_enc', 'Relationship_Status_enc']

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 5
#       2 X_train = ['Age', 'Avg_Daily_Usage_Hours', 'Sleep_Hours_Per_Night','Mental_Health_Score', 'Conflicts_Over_Social_Media']
#       3 X_test = ['Gender_enc', 'Academic_Level_enc', 'Most_Used_Platform_enc', 'Affects_Academic_Performance_enc', 'Relationship_Status_enc']
# ----> 5 X_train_scaled = scaler.fit_transform(X_train)
#       6 X_test_scaled = scaler.transform(X_test)
#
# File c:\Users\lanat\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
# ...
